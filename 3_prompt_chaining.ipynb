# %%
from langgraph.graph import StateGraph , START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
model= ChatOpenAI(api_key=os.getenv("LANGCHAIN_API_KEY"))

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state:BlogState)->BlogState:
    title= state["title"]
    prompt= f"Generate a detail outlline for a blog on the topic - {title}"
    outline= model.invoke(prompt).content
    state["outline"]= outline
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title= state["title"]
    outline= state["outline"]
    prompt= f"Write a blog post based on the following title and outline.\nTitle: {title}\nOutline: {outline}"
    content= model.invoke(prompt).content
    state["content"]= content
    return state

# %%
graph = StateGraph(BlogState)
graph.add_node("create_outline",create_outline)

graph.add_node("create_blog",create_blog)

graph.add_edge(START, "create_outline")
graph.add_edge("create_outline", "create_blog")
graph.add_edge("create_blog", END)

workflow=graph.compile()

# %%
initial_state= {"title": "Virat Kohli's career highlights"}
final_state= workflow.invoke(initial_state)
print(final_state["content"])
# Out:
# Virat Kohli's career highlights
#
# Virat Kohli, the Indian cricketing superstar, has captured the hearts of fans around the world with his exceptional talent and unwavering dedication to the sport. From his early days as a promising young cricketer to his current status as one of the greatest players in the game, Kohli's career has been nothing short of remarkable. In this blog post, we will take a closer look at some of the key highlights of Virat Kohli's illustrious career.
#
# Introduction
#
# Virat Kohli burst onto the cricketing scene as a young and ambitious player with a fierce determination to succeed. Over the years, he has established himself as one of the greatest cricketers of all time, breaking records and setting new benchmarks in the sport.
#
# Early Career Highlights
#
# ...

# %%
print(final_state["outline"])
# Out:
# I. Introduction
#     A. Brief overview of Virat Kohli's career as a cricketer
#     B. Explanation of why he is considered one of the greatest cricketers of all time
#
# II. Early Career Highlights
#     A. Debut for the Indian national team
#     B. Performance in Under-19 World Cup
#     C. ODI debut and breakthrough performances
#
# III. Test Career Highlights
#     A. First Test century
#     B. Captaincy of the Indian Test team
#     C. Record-breaking performances
#
# IV. ODI Career Highlights
#     A. Rise to the top of ICC rankings
#     B. Centuries in chases and high-pressure situations
#     C. Captaincy of the Indian ODI team
#
# V. T20 Career Highlights
#     A. Performance in ICC T20 World Cup
#     B. Record-breaking innings in T20 matches
#
# VI. Achievements and Records
#     A. Records held by Virat Kohli in all formats of the game
#     B. Awards and accolades received throughout his career
#
# VII. Off-field Achievements
#     A. Charity work and philanthropy
# ...
